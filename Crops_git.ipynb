# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('crops.csv')

# %%
data.head()
# Out:
#    S.No                      Crop  Area in Hect  Production (Tonnes)  \
# 0     1         Paddy* in Cereals       1905726            5792415.0
# 1     2  Cholam(Jowar) in Cereals        243465             246981.0
# 2     3   Cumbu(Bajra) in Cereals         49482              77369.0
# 3     4           Ragi in Cereals         75650             171096.0
# 4     5          Maize in Cereals        230489            1027536.0
#
#    Productivity (in Kg./Hec.)
# 0                      3039.0
# 1                      1014.0
# 2                      1564.0
# 3                      2262.0
# 4                      4458.0

# %%
data.fillna(method='bfill',inplace=True)

# %%
data.shape
# Out:
# (28, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 5 columns):
# S.No                          28 non-null int64
# Crop                          28 non-null object
# Area in Hect                  28 non-null int64
# Production (Tonnes)           27 non-null float64
# Productivity (in Kg./Hec.)    27 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.2+ KB

# %%
data.describe()
# Out:
#             S.No  Area in Hect  Production (Tonnes)  \
# count  28.000000  2.800000e+01         2.700000e+01
# mean   14.464286  6.618379e+05         4.526486e+06
# std     8.207865  1.198454e+06         1.091295e+07
# min     1.000000  5.366000e+03         1.862000e+03
# 25%     7.750000  4.797175e+04         2.452900e+04
# 50%    14.500000  2.010775e+05         1.710960e+05
# 75%    21.250000  6.939555e+05         9.825430e+05
# max    28.000000  5.752664e+06         3.452962e+07
#
#        Productivity (in Kg./Hec.)
# count                   27.000000
# mean                  3128.427407
# std                   5633.514530
# min                    108.000000
# 25%                    404.000000
# 50%                   1040.000000
# 75%                   2358.000000
# max                  20154.200000

# %%
plt.scatter(data['Crop'],data['Area in Hect'])

# %%
data.drop('S.No',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Crop', 'Area in Hect', 'Production (Tonnes)',
#        'Productivity (in Kg./Hec.)'],
#       dtype='object')

# %%
sns.pairplot(data)

# %%
sns.barplot(x='Area in Hect',y='Production (Tonnes)',hue='Crop',data=data)
locs='upper right'

# %%
plt.bar(data['Crop'],data['Productivity (in Kg./Hec.)'])
plt.show()

# %%
sns.stripplot(x='Area in Hect',y='Production (Tonnes)',data=data)

# %%
sns.distplot(data['Area in Hect'],kde=False,bins=20)

# %%
sns.pairplot(data,hue='Production (Tonnes)')
# Out:
# C:\Users\personal\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\personal\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.jointplot(x='Production (Tonnes)',y='Area in Hect',data=data,kind='scatter')
